# %%
# Clone git repository.
# !git clone https://github.com/jamesthomson/Evolution_of_Pop_Lyrics/
# Out:
# Cloning into 'Evolution_of_Pop_Lyrics'...
# remote: Counting objects: 15, done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 15 (delta 1), reused 15 (delta 1), pack-reused 0
# Unpacking objects: 100% (15/15), done.

# %%
# Files from the cloned git repository.
# !ls Evolution_of_Pop_Lyrics/data
# Out:
# scraped_lyrics.tsv

# %%
import pandas as pd
lyrics = pd.set_option('display.max_colwidth', -1)
lyrics = pd.read_csv('Evolution_of_Pop_Lyrics/data/scraped_lyrics.tsv', sep="\t")
lyrics.head(10)
# Out:
#    recording_id                                       artist_name  \
# 0  1             Suzanne Vega
# 1  2             Janet Jackson ft Carly Simon
# 2  3             Neneh Cherry
# 3  4             Neneh Cherry
# 4  5             Junior M.A.F.I.A. Featuring The Notorious B.I.G.
# 5  6             Junior M.A.F.I.A.
# 6  7             Missy "Misdemeanor" Elliott Featuring Da Brat
# 7  8             Nas
# 8  9             Tweet
# 9  10            Fabolous
#
#                                            track_name  \
# 0  Solitude Standing
# 1  Son Of A Gun (Betcha Think This Song Is About You)
# 2  Heart
# 3  Kisses On The Wind
# 4  Get Money
# 5  Player's Anthem
# 6  Sock It 2 Me
# 7  If I Ruled The World
# 8  Oops (Oh My)
# 9  Young'n (Holla Back)
#
#                   lyrics_artist       lyrics_track  \
# 0  Solitude Standing             Suzanne Vega
# 1  Earth Song                    Michael Jackson
# 2  Lyrics Not Found              Lyrics Not Found
# ...

# %%
found_lyrics=lyrics[lyrics['lyrics']!='Lyrics Not found']
